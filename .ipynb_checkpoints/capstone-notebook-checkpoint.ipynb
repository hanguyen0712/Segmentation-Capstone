# %% [markdown]
# ### Part 1: Create the SF dataset with neighborhood coordinates

# %%
#import libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import geocoder
from geopy.geocoders import Nominatim
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import folium
import statistics

# %%
#scrape information from healthysf.org
web = requests.get("http://www.healthysf.org/bdi/outcomes/zipmap.htm").text
soup = BeautifulSoup(web, 'lxml')
table = soup.find_all('table')[4]
table_string = pd.read_html(str(table))

#put zip code and neighborhood name into a dataframe
df = pd.DataFrame({'Zip Code':table_string[0][0], 'Neighborhood':table_string[0][1]}, columns = ['Zip Code', 'Neighborhood'])
df.head(5)
# Out:
#    Zip Code                             Neighborhood
# 0  Zip Code                             Neighborhood
# 1     94102  Hayes Valley/Tenderloin/North of Market
# 2     94103                          South of Market
# 3     94107                             Potrero Hill
# 4     94108                                Chinatown

# %%
###data cleaning

#drop 1st and last row
df = df.drop([0, len(df['Zip Code']) - 1], axis = 0).reset_index(drop = True)
df
# Out:
#    Zip Code                             Neighborhood
# 0     94102  Hayes Valley/Tenderloin/North of Market
# 1     94103                          South of Market
# 2     94107                             Potrero Hill
# 3     94108                                Chinatown
# 4     94109             Polk/Russian Hill (Nob Hill)
# 5     94110             Inner Mission/Bernal Heights
# 6     94112       Ingelside-Excelsior/Crocker-Amazon
# 7     94114                        Castro/Noe Valley
# 8     94115               Western Addition/Japantown
# 9     94116                     Parkside/Forest Hill
# 10    94117                           Haight-Ashbury
# 11    94118                           Inner Richmond
# 12    94121                           Outer Richmond
# 13    94122                                   Sunset
# 14    94123                                   Marina
# 15    94124                    Bayview-Hunters Point
# 16    94127    St. Francis Wood/Miraloma/West Portal
# ...

# %%
#create latitude and longitude column
df['Latitude'] = ""
df['Longitude'] = ""

# %%
for zip_code in df['Zip Code']: 
    geolocator = Nominatim(user_agent='sflocator')
    loc = geolocator.geocode('{}, San Francisco, California'.format(zip_code))
    df['Latitude'][df[df['Zip Code']== zip_code].index.values.astype(int)[0]] = loc.latitude
    df['Longitude'][df[df['Zip Code']== zip_code].index.values.astype(int)[0]] = loc.longitude

# %%
#save file for backup
df.to_csv("sf-neighborhood-coords.csv")

# %% [markdown]
# ### Part 2: Fetch data for housing price

# %%
#scrape information from Property Shark
cookies = {'1P_JAR':'2019-6-8-1','ANID':'AHWqTUkRrtu1rQRuaJ06ruvv72G-4n8_R98IZOfUfUWVVtcM_PpIXDYX6Q7SHoFc','ANID':'AHWqTUnWY3BuTFXxD1bqsHoVeCGCU7D8JQpiQZzAOg431V1jTLVnSGJqeyhWoDnW','APISID':'38QMlLg_nf0J2r8K/AB5XgOtYRAg7HSwAA','APISID':'38QMlLg_nf0J2r8K/AB5XgOtYRAg7HSwAA','DSID':'ADyxukt-GpG7MpfEM58ZFO_vSjbgbyUZ4Ksy4ElVCQnKO6vpCsoF-pmqXjXTVqHxbR5xKbbJBGA0wqxD8utnqgvPeQCpIBvsWy4yAhJK0dutj8d3Oh6nSh8','DV':'wwsEjaf4XeYuUHFnxQKTMX8vaWRLs5brkYfywieOAeteAAA','HSID':'A3gOhCGOCYNdLgyvw','HSID':'AdGqSxkjR5PbJ2ILA','IDE':'AHWqTUlACS1QrNVlOfimfoUU5u8TmFiHzJRHbFD8tjK5tHuigtcAa5mexCHMP5A2','NID':'182=a2wy9s0CczHN_ByTxoamIgFgvLxul868C20hqN6N4gGMLBgn0MMR_eFhgX2YYPxatleQj-Dn79wTJDT9QOBKxkDHelTk2VQf4yeem8EebMYzNT-CeJOBCJeRLs20YlPP8teBRc1mnKT2fEumrzgmwTX3VogFYoxyihXhGrze0LQqaRJuOmSDRw46xGLH2jjBFwrkmWztcWe4Jh3t2awnpspLq6t3Sm4umPQo-HP5uv9TsG5dB25lPQhg-bJi_PCjeb4tJt46VMeK30x1u-RYcA5CI2XEoYQA_ELVbVZ3XA-aReVoF1Z6_d9QLsDrWjj37NcN-BFhpe7y43S4No2bL3Je8tpdVP8','NID':'185=3TtneBpcjsUjiu6Lk3SjZHqgSWzbhbdj2H2RUFTg3EwovBoZG_m-C-UZ6NDt8AtceB-45tfWS-FZxtijCvpC1uNYSKaw9iKjIvXRGkj6qYZgnAIkDdRYoH-OG3tYTb4EQsQIZw1gq839Q8q6BcEuxWVYe3rusQYhtsCaQZ35rISarS5dBQhvlpjkcnG8SfAgXhaQMxVfEzIAYYaZTPSRzgrkKCa39F1R5cc4K0YkLpwMa-9jUFGJ7w8Noilot4BH1eWFyLvbgu9bldQ4QKSY4Sv6kyTbEWdb4X7w8FUIKaBfktg-Qktz-u0u9fNooLLDll0GZyJE31qNt58NRM2dJP8gEkFu74M8qBQ1w7MYppr-ljTApluLJNLQL9gMg6m206xKFho1cEpMc64','OTZ':'4938734_28_28__28_','SAPISID':'Vy_ecN3O-ZL_Dy_L/ACf8ZOClpHxMF0TNa','SAPISID':'Vy_ecN3O-ZL_Dy_L/ACf8ZOClpHxMF0TNa','SID':'egchz2hCzHGDK8fDsULQXzaeVEszzGvJPWnUpjFp60mJIWbaK0RPXEdE-iN9sP20HmiZdQ.','SID':'egchz2hCzHGDK8fDsULQXzaeVEszzGvJPWnUpjFp60mJIWbaK0RPXEdE-iN9sP20HmiZdQ.','SIDCC':'AN0-TYsqb7m728eZ19h4zhUsLf4l_cxgKtJyFntwEP2w4_hiAtu23MMaSIAmEo9GLmtokWP-5ddM','SSID':'Ab5RcSUeEj_oh5qGj','SSID':'Af65ZOJ7DFUnPioQT','__gads':'ID=2a7b46eb030577fa:T=1505522617:S=ALNI_MYKOMwzflE2aWRiRJJCzgyd5TUM0A','__idcontext':'eyJjb29raWVJRCI6IlVJQkxIUExNRlRTTkIyUFpFUU1JS0E2UlFIUzZXTlZKMlE0WTRQSzZJRE1RPT09PSIsImRldmljZUlEIjoiVUlCTEhQTE1FUDROTFpHQ0ZOQzRBMlgyWUhHSlU1NktXWTQyU0xRSE1XQlE9PT09IiwiaXYiOiJRSjNPVzJOMkdUNFVEWEdMNlZJUFY0N0ZFND09PT09PSIsInYiOjF9','__xsptplus814':'814.2.1543043300.1543045082.13%233%7Cwww.flyscoot.com%7C%7C%7C%7C%23%23Z8qcvt0wnym8BBI80mrMQ70VF9ju5ooV%23','_fbc':'fb.1.1559883029124.IwAR30fhybog-RgN7tV1Kvf2iG2T3X6ksU2BYm2-QsbFlrIZTgzAx55je9ACk','_fbp':'fb.1.1550038867463.1987533212','_ga':'GA1.2.950836956.1559897414','_gid':'GA1.2.1335605111.1559897414','_ym_uid':'1519023791766792539','incap_ses_626_1731432':'BPJ/CH7Tan+hm3+i1gCwCKMQ+1wAAAAAmFfqgGmzW8bND1wDJI1JIg==','session':'10.97.95.111.1559897414653316','visid_incap_1731432':'LsrpaOF+QvmAL7KxYndh1Tol+lwAAAAAQkIPAAAAAACAwLeMARtP59CsPHwpRGQk88ona65ka2bh'}
webh = requests.get("https://www.propertyshark.com/Real-Estate-Reports/2017/09/28/expensive-zip-codes-san-francisco/", cookies = cookies).text
souph = BeautifulSoup(webh, 'lxml')
print(souph.prettify())

tableh = souph.find('table', {'class': 'tablepress tablepress-id-185'})
tableh_string = pd.read_html(str(tableh))
#put house price data into a dataframe
house_price = tableh_string[0]
house_price.head(5)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    The Most Expensive Zip Codes in San Francisco | PropertyShark
#   </title>
#   <!-- This site is optimized with the Yoast SEO Premium plugin v9.6.1 - https://yoast.com/wordpress/plugins/seo/ -->
#   <link href="https://www.propertyshark.com/Real-Estate-Reports/2017/09/28/expensive-zip-codes-san-francisco/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="The Most Expensive Zip Codes in San Francisco | PropertyShark" property="og:title"/>
#   <meta content="Key Takeaways: 94105 is the priciest zip code in San Francisco The Financial District (94104)..." property="og:description"/>
# ...

# %%
#remove unnecessary columns
house_price = house_price.drop(['Rank', 'MEDIAN PRICE/SQFT 2016', 'Y-o-Y Change'], axis = 1).reset_index(drop = True)
#convert zip code to string type for consistency with df
house_price['ZIP CODE'] = house_price['ZIP CODE'].astype(str)
#rename ZIP CODE column to Zip Code for consistency with df
house_price.rename(columns = {'ZIP CODE': 'Zip Code'}, inplace = True)

# %%
### merge housing data with df

#check if all the zip codes in df are also in house_price
df['Zip Code'].isin(house_price['Zip Code']).value_counts()

#left join
df = pd.merge(df, house_price, on = 'Zip Code', how = 'left')
df.head()
# Out:
#   Zip Code                             Neighborhood Latitude Longitude  \
# 0    94102  Hayes Valley/Tenderloin/North of Market  37.7795  -122.418
# 1    94103                          South of Market  37.7744  -122.411
# 2    94107                             Potrero Hill  37.7923  -122.409
# 3    94108                                Chinatown  37.7911  -122.407
# 4    94109             Polk/Russian Hill (Nob Hill)  37.7941  -122.421
#
#   MEDIAN PRICE/SQFT 2017
# 0                 $1,005
# 1                 $1,003
# 2                 $1,035
# 3                 $1,189
# 4                   $992

# %%
#remove dollar sign from 'MEDIAN PRICE/SQFT 2017' and change into int type
df['MEDIAN PRICE/SQFT 2017'] = df['MEDIAN PRICE/SQFT 2017'].str.replace(',','')
df['MEDIAN PRICE/SQFT 2017'] = df['MEDIAN PRICE/SQFT 2017'].str.replace('$','')
df['MEDIAN PRICE/SQFT 2017'] = pd.to_numeric(df['MEDIAN PRICE/SQFT 2017'])
df.head()
# Out:
#   Zip Code                             Neighborhood Latitude Longitude  \
# 0    94102  Hayes Valley/Tenderloin/North of Market  37.7795  -122.418
# 1    94103                          South of Market  37.7744  -122.411
# 2    94107                             Potrero Hill  37.7923  -122.409
# 3    94108                                Chinatown  37.7911  -122.407
# 4    94109             Polk/Russian Hill (Nob Hill)  37.7941  -122.421
#
#    MEDIAN PRICE/SQFT 2017
# 0                    1005
# 1                    1003
# 2                    1035
# 3                    1189
# 4                     992

# %% [markdown]
# ### Part 3: Fetch data for nearby venues

# %%
#get the latitude and longitude of San Francisco
address = 'San Francisco, California'

geolocator = Nominatim(user_agent = 'sflocator')
location = geolocator.geocode(address)
city_lat = location.latitude
city_lng = location.longitude
print('The geographical coordinates of San Francisco are {}, {}'.format(city_lat, city_lng))
# Out:
# The geographical coordinates of San Francisco are 37.7792808, -122.4192363

# %%
statistics.median(df['MEDIAN PRICE/SQFT 2017']
# Out:
#   File "<ipython-input-57-f57482beaa1f>", line 1
#     statistics.median(df['MEDIAN PRICE/SQFT 2017']
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
#map of San Francisco with neighborhoods superimposed on top
sf_map = folium.Map(location = [city_lat, city_lng], zoom_start = 12)

#add markers
def label_color(price):
    if price >= df['MEDIAN PRICE/SQFT 2017'].quantile(.75):
        return '#f44242'
    elif price < df['MEDIAN PRICE/SQFT 2017'].quantile(.75) and price >= statistics.median(df['MEDIAN PRICE/SQFT 2017']):
        return '#f4d742'
    elif price < statistics.median(df['MEDIAN PRICE/SQFT 2017']) and price >= df['MEDIAN PRICE/SQFT 2017'].quantile(.25):
        return '#70f441'
    else:
        return '#418bf4'

for lat, lng, neighborhood, price in zip(df['Latitude'], df['Longitude'], df['Neighborhood'], df['MEDIAN PRICE/SQFT 2017']):
    label = '{}:{}'.format(neighborhood, price)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker([lat, lng], radius = 5, popup = label, color = label_color(price), fill = True, fill_color = label_color(price), fill_opacity = 0.8, parse_html = False).add_to(sf_map)

sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Findings: Houses in downtown neighborhoods tend to be pricier than those in the outskirt, with the exception of Sunset.

# %%
#define foursquare credentials and version
CLIENT_ID = 'HPOULZHL1DFLSPAYO5F3PR51O1A3KWEOU3320AHX0DTEDIQV'
CLIENT_SECRET = 'YBVY1UPRSHIX1NR3DFCG3ST2FV4IU2XSLLU40YOVY4QJL0WO'
VERSION = '20180605'

# %%
#explore popular venues in all neighborhoods
def getNearbyVenues(names, latitudes, longitudes, radius = 1000, limit = 750):
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, limit)
        
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        venues_list.append([(name, lat, lng, v['venue']['name'], v['venue']['location']['lat'], v['venue']['location']['lng'], v['venue']['categories'][0]['name']) for v in results])
    
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']
    
    return(nearby_venues)

sfvenues = getNearbyVenues(names = df['Neighborhood'], latitudes = df['Latitude'], longitudes = df['Longitude'])
sfvenues
# Out:
#                                  Neighborhood  Neighborhood Latitude  \
# 0     Hayes Valley/Tenderloin/North of Market              37.779481
# 1     Hayes Valley/Tenderloin/North of Market              37.779481
# 2     Hayes Valley/Tenderloin/North of Market              37.779481
# 3     Hayes Valley/Tenderloin/North of Market              37.779481
# 4     Hayes Valley/Tenderloin/North of Market              37.779481
# 5     Hayes Valley/Tenderloin/North of Market              37.779481
# 6     Hayes Valley/Tenderloin/North of Market              37.779481
# 7     Hayes Valley/Tenderloin/North of Market              37.779481
# 8     Hayes Valley/Tenderloin/North of Market              37.779481
# 9     Hayes Valley/Tenderloin/North of Market              37.779481
# 10    Hayes Valley/Tenderloin/North of Market              37.779481
# 11    Hayes Valley/Tenderloin/North of Market              37.779481
# 12    Hayes Valley/Tenderloin/North of Market              37.779481
# ...

# %%
#count how many venues are returned for each neighborhood
sfvenues.groupby('Neighborhood').count()
# Out:
#                                          Neighborhood Latitude  \
# Neighborhood
# Bayview-Hunters Point                                       29
# Castro/Noe Valley                                          100
# Chinatown                                                  100
# Haight-Ashbury                                             100
# Hayes Valley/Tenderloin/North of Market                    100
# Ingelside-Excelsior/Crocker-Amazon                          98
# Inner Mission/Bernal Heights                               100
# Inner Richmond                                             100
# Lake Merced                                                 41
# Marina                                                     100
# North Beach/Chinatown                                      100
# Outer Richmond                                             100
# Parkside/Forest Hill                                       100
# Polk/Russian Hill (Nob Hill)                               100
# ...

# %% [markdown]
# Findings: The outskirt neighborhoods have fewer venues (most are below 100) and also have lower house prices.

# %%
#unique categories can be curated from all venues
len(sfvenues['Venue Category'].unique())
# Out:
# 262

# %%
#onehot encoding
sfonehot = pd.get_dummies(sfvenues[['Venue Category']], prefix = '', prefix_sep = '')
#add neighborhood column back to dataframe
sfonehot['Neighborhood'] = sfvenues['Neighborhood']
#group rows by neighborhoods, take means of frequency of occurence
sfgrouped = sfonehot.groupby('Neighborhood').mean().reset_index()

# %%
#return 10 most popular venues in each neighborhood

#function to sort the venues in descending order
def return_most_common_venues(row, num_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending = False)
    
    return row_categories_sorted.index.values[0:num_venues]

#return 10 most popular venues for each neighborhood
num_venues = 10
indicators = ['st', 'nd', 'rd']
#create columns according to the number of top venues
columns = ['Neighborhood']

#name columns
for index in np.arange(num_venues):
    #column name for 1st, 2nd and 3rd most popular venues
    try:
        columns.append('{}{} Most Common Venue'.format(index + 1, indicators[index]))
    #column name for 4th most popular venue onwards
    except:
        columns.append('{}th Most Common Venue'.format(index + 1))
        
#create new dataframe
neigh_venues_sorted = pd.DataFrame(columns = columns)
neigh_venues_sorted['Neighborhood'] = sfgrouped['Neighborhood']

for index in np.arange(sfgrouped.shape[0]):
    neigh_venues_sorted.iloc[index, 1:] = return_most_common_venues(sfgrouped.iloc[index, :], num_venues)

neigh_venues_sorted
# Out:
#                                Neighborhood 1st Most Common Venue  \
# 0                     Bayview-Hunters Point   American Restaurant
# 1                         Castro/Noe Valley               Gay Bar
# 2                                 Chinatown           Coffee Shop
# 3                            Haight-Ashbury           Coffee Shop
# 4   Hayes Valley/Tenderloin/North of Market           Coffee Shop
# 5        Ingelside-Excelsior/Crocker-Amazon           Pizza Place
# 6              Inner Mission/Bernal Heights    Mexican Restaurant
# 7                            Inner Richmond                  Park
# 8                               Lake Merced                  Park
# 9                                    Marina                   Spa
# 10                    North Beach/Chinatown    Italian Restaurant
# 11                           Outer Richmond                  Café
# 12                     Parkside/Forest Hill    Chinese Restaurant
# ...

# %% [markdown]
# ### Part 4: Neighborhood clusters

# %%
#drop neighborhood column from the sfgrouped dataframe
sfgrouped_cluster = sfgrouped.drop('Neighborhood', axis = 1)

# %%
### find optimal k

sum_of_squared_distances = []
K = range(1, 10)
for k in K:
    #run k-means clustering
    kmeans = KMeans(n_clusters = k, random_state = 123).fit(sfgrouped_cluster)
    sum_of_squared_distances.append(kmeans.inertia_)
    
#plot 
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')
plt.title('Elbow method to find optimal k')
plt.show()

# %%
#choose k = 4
k = 4
#run k-means clustering
kmeans = KMeans(n_clusters = k, random_state = 123).fit(sfgrouped_cluster)

#check cluster labels generated for each row in the frame
kmeans.labels_[0:20]
# Out:
# array([3, 1, 1, 1, 1, 0, 1, 0, 3, 1, 0, 0, 0, 1, 1, 1, 0, 1, 2, 3])

# %%
#add clustering labels
neigh_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

#merge lustering results back in with the main data
sfmerged = df
sfmerged = sfmerged.join(neigh_venues_sorted.set_index('Neighborhood'), on = 'Neighborhood')
sfmerged.head()
# Out:
#   Zip Code                             Neighborhood Latitude Longitude  \
# 0    94102  Hayes Valley/Tenderloin/North of Market  37.7795  -122.418
# 1    94103                          South of Market  37.7744  -122.411
# 2    94107                             Potrero Hill  37.7923  -122.409
# 3    94108                                Chinatown  37.7911  -122.407
# 4    94109             Polk/Russian Hill (Nob Hill)  37.7941  -122.421
#
#    MEDIAN PRICE/SQFT 2017  Cluster Labels 1st Most Common Venue  \
# 0                    1005               1           Coffee Shop
# 1                    1003               1          Cocktail Bar
# 2                    1035               1           Coffee Shop
# 3                    1189               1           Coffee Shop
# 4                     992               1    Italian Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar     French Restaurant              Beer Bar
# ...

# %%
#create map
map_clusters = folium.Map(location = [city_lat, city_lng], zoom_start = 11)

#set color scheme
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#add markers
markers_colors = []
for lat, lon, neighborhood, cluster, price in zip (sfmerged['Latitude'], sfmerged['Longitude'], sfmerged['Neighborhood'], sfmerged['Cluster Labels'], sfmerged['MEDIAN PRICE/SQFT 2017']):
    label = folium.Popup(str(neighborhood) + ', Cluster ' + str(cluster) + ', Median house price ' + str(price), parse_html = True)
    folium.CircleMarker([lat, lon], radius = 5, popup = label, color = rainbow[cluster - 1], fill = True, fill_color = rainbow[cluster  - 1], fill_opacity = 0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
