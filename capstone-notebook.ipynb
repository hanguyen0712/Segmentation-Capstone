# %% [markdown]
# ### Part 1: Create the SF dataset

# %%
#import libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import geocoder
from geopy.geocoders import Nominatim
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %%
#scrape information from healthysf.org
web = requests.get("http://www.healthysf.org/bdi/outcomes/zipmap.htm").text
soup = BeautifulSoup(web, 'lxml')
table = soup.find_all('table')[4]
table_string = pd.read_html(str(table))

#put zip code and neighborhood name into a dataframe
df = pd.DataFrame({'Zip Code':table_string[0][0], 'Neighborhood':table_string[0][1]}, columns = ['Zip Code', 'Neighborhood'])
df.head(5)
# Out:
#    Zip Code                             Neighborhood
# 0  Zip Code                             Neighborhood
# 1     94102  Hayes Valley/Tenderloin/North of Market
# 2     94103                          South of Market
# 3     94107                             Potrero Hill
# 4     94108                                Chinatown

# %%
###data cleaning

#drop 1st and last row
df = df.drop([0, len(df['Zip Code']) - 1], axis = 0).reset_index(drop = True)
df
# Out:
#    Zip Code                             Neighborhood
# 0     94102  Hayes Valley/Tenderloin/North of Market
# 1     94103                          South of Market
# 2     94107                             Potrero Hill
# 3     94108                                Chinatown
# 4     94109             Polk/Russian Hill (Nob Hill)
# 5     94110             Inner Mission/Bernal Heights
# 6     94112       Ingelside-Excelsior/Crocker-Amazon
# 7     94114                        Castro/Noe Valley
# 8     94115               Western Addition/Japantown
# 9     94116                     Parkside/Forest Hill
# 10    94117                           Haight-Ashbury
# 11    94118                           Inner Richmond
# 12    94121                           Outer Richmond
# 13    94122                                   Sunset
# 14    94123                                   Marina
# 15    94124                    Bayview-Hunters Point
# 16    94127    St. Francis Wood/Miraloma/West Portal
# 17    94131                     Twin Peaks-Glen Park
# 18    94132                              Lake Merced
# 19    94133                    North Beach/Chinatown
# 20    94134              Visitacion Valley/Sunnydale

# %%
#create latitude and longitude column
df['Latitude'] = ""
df['Longitude'] = ""

# %%
for zip_code in df['Zip Code']: 
    geolocator = Nominatim(user_agent='sflocator')
    loc = geolocator.geocode('{}, San Francisco, California'.format(zip_code))
    df['Latitude'][df[df['Zip Code']== zip_code].index.values.astype(int)[0]] = loc.latitude
    df['Longitude'][df[df['Zip Code']== zip_code].index.values.astype(int)[0]] = loc.longitude

# %%
df
# Out:
#    Zip Code                             Neighborhood Latitude Longitude
# 0     94102  Hayes Valley/Tenderloin/North of Market  37.7795  -122.418
# 1     94103                          South of Market  37.7744  -122.411
# 2     94107                             Potrero Hill  37.7923  -122.409
# 3     94108                                Chinatown  37.7911  -122.407
# 4     94109             Polk/Russian Hill (Nob Hill)  37.7941  -122.421
# 5     94110             Inner Mission/Bernal Heights  37.7533  -122.417
# 6     94112       Ingelside-Excelsior/Crocker-Amazon  37.7234  -122.444
# 7     94114                        Castro/Noe Valley  37.7614  -122.435
# 8     94115               Western Addition/Japantown  37.7839  -122.435
# 9     94116                     Parkside/Forest Hill  37.7464  -122.473
# 10    94117                           Haight-Ashbury  37.7793  -122.419
# 11    94118                           Inner Richmond   37.776  -122.457
# 12    94121                           Outer Richmond  37.7834  -122.492
# 13    94122                                   Sunset  37.7793  -122.419
# 14    94123                                   Marina  37.7989   -122.43
# 15    94124                    Bayview-Hunters Point  37.7163  -122.395
# 16    94127    St. Francis Wood/Miraloma/West Portal  37.7396  -122.465
# 17    94131                     Twin Peaks-Glen Park  37.7506  -122.452
# 18    94132                              Lake Merced  37.7175  -122.474
# 19    94133                    North Beach/Chinatown  37.7981  -122.406
# 20    94134              Visitacion Valley/Sunnydale  37.7144  -122.411

# %% [markdown]
# ### Part 2: Create clusters

# %%
#get the latitude and longitude of San Francisco
address = 'San Francisco, California'

geolocator = Nominatim(user_agent = 'sflocator')
location = geolocator.geocode(address)
city_lat = location.latitude
city_lng = location.longitude
print('The geographical coordinates of San Francisco are {}, {}'.format(city_lat, city_lng))
# Out:
# The geographical coordinates of San Francisco are 37.7792808, -122.4192363

# %%
#map of San Francisco with neighborhoods superimposed on top
sf_map = folium.Map(location = [city_lat, city_lng], zoom_start = 12)

#add markers
for lat, lng, neighborhood in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker([lat, lng], radius = 5, popup = label, color = 'orange', fill = True, fill_color = '#f49842', fill_opacity = 0.6, parse_html = False).add_to(sf_map)
    
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#define foursquare credentials and version
CLIENT_ID = 'HPOULZHL1DFLSPAYO5F3PR51O1A3KWEOU3320AHX0DTEDIQV'
CLIENT_SECRET = 'YBVY1UPRSHIX1NR3DFCG3ST2FV4IU2XSLLU40YOVY4QJL0WO'
VERSION = '20180605'

# %%
#explore popular venues in all neighborhoods
def getNearbyVenues(names, latitudes, longitudes, radius = 500, limit = 50):
    venues_list = []
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, limit)
        
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        venues_list.append([(name, lat, lng, v['venue']['name'], v['venue']['location']['lat'], v['venue']['location']['lng'], v['venue']['categories'][0]['name']) for v in results])
    
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category']
    
    return(nearby_venues)

sfvenues = getNearbyVenues(names = df['Neighborhood'], latitudes = df['Latitude'], longitudes = df['Longitude'])
sfvenues
# Out:
#                                 Neighborhood  Neighborhood Latitude  \
# 0    Hayes Valley/Tenderloin/North of Market              37.779481
# 1    Hayes Valley/Tenderloin/North of Market              37.779481
# 2    Hayes Valley/Tenderloin/North of Market              37.779481
# 3    Hayes Valley/Tenderloin/North of Market              37.779481
# 4    Hayes Valley/Tenderloin/North of Market              37.779481
# 5    Hayes Valley/Tenderloin/North of Market              37.779481
# 6    Hayes Valley/Tenderloin/North of Market              37.779481
# 7    Hayes Valley/Tenderloin/North of Market              37.779481
# 8    Hayes Valley/Tenderloin/North of Market              37.779481
# 9    Hayes Valley/Tenderloin/North of Market              37.779481
# 10   Hayes Valley/Tenderloin/North of Market              37.779481
# 11   Hayes Valley/Tenderloin/North of Market              37.779481
# 12   Hayes Valley/Tenderloin/North of Market              37.779481
# 13   Hayes Valley/Tenderloin/North of Market              37.779481
# 14   Hayes Valley/Tenderloin/North of Market              37.779481
# 15   Hayes Valley/Tenderloin/North of Market              37.779481
# 16   Hayes Valley/Tenderloin/North of Market              37.779481
# 17   Hayes Valley/Tenderloin/North of Market              37.779481
# 18   Hayes Valley/Tenderloin/North of Market              37.779481
# 19   Hayes Valley/Tenderloin/North of Market              37.779481
# 20   Hayes Valley/Tenderloin/North of Market              37.779481
# 21   Hayes Valley/Tenderloin/North of Market              37.779481
# 22   Hayes Valley/Tenderloin/North of Market              37.779481
# 23   Hayes Valley/Tenderloin/North of Market              37.779481
# 24   Hayes Valley/Tenderloin/North of Market              37.779481
# 25   Hayes Valley/Tenderloin/North of Market              37.779481
# 26   Hayes Valley/Tenderloin/North of Market              37.779481
# 27   Hayes Valley/Tenderloin/North of Market              37.779481
# 28   Hayes Valley/Tenderloin/North of Market              37.779481
# 29   Hayes Valley/Tenderloin/North of Market              37.779481
# ..                                       ...                    ...
# 745                    North Beach/Chinatown              37.798105
# 746                    North Beach/Chinatown              37.798105
# 747                    North Beach/Chinatown              37.798105
# 748                    North Beach/Chinatown              37.798105
# 749                    North Beach/Chinatown              37.798105
# 750                    North Beach/Chinatown              37.798105
# 751                    North Beach/Chinatown              37.798105
# 752                    North Beach/Chinatown              37.798105
# 753                    North Beach/Chinatown              37.798105
# 754                    North Beach/Chinatown              37.798105
# 755                    North Beach/Chinatown              37.798105
# 756                    North Beach/Chinatown              37.798105
# 757                    North Beach/Chinatown              37.798105
# 758                    North Beach/Chinatown              37.798105
# 759                    North Beach/Chinatown              37.798105
# 760                    North Beach/Chinatown              37.798105
# 761                    North Beach/Chinatown              37.798105
# 762                    North Beach/Chinatown              37.798105
# 763                    North Beach/Chinatown              37.798105
# 764                    North Beach/Chinatown              37.798105
# 765                    North Beach/Chinatown              37.798105
# 766                    North Beach/Chinatown              37.798105
# 767                    North Beach/Chinatown              37.798105
# 768                    North Beach/Chinatown              37.798105
# 769                    North Beach/Chinatown              37.798105
# 770              Visitacion Valley/Sunnydale              37.714384
# 771              Visitacion Valley/Sunnydale              37.714384
# 772              Visitacion Valley/Sunnydale              37.714384
# 773              Visitacion Valley/Sunnydale              37.714384
# 774              Visitacion Valley/Sunnydale              37.714384
#
#      Neighborhood Longitude                                 Venue  \
# 0               -122.418229                      Asian Art Museum
# 1               -122.418229        Louise M. Davies Symphony Hall
# 2               -122.418229                        Herbst Theater
# 3               -122.418229                          Philz Coffee
# 4               -122.418229              War Memorial Opera House
# 5               -122.418229                  San Francisco Ballet
# 6               -122.418229            Off the Grid: Civic Center
# 7               -122.418229                        The Nutcracker
# 8               -122.418229  Siam Orchid Traditional Thai Massage
# 9               -122.418229                    War Memorial Court
# 10              -122.418229                   SHN Orpheum Theatre
# 11              -122.418229                          Ananda Fuara
# 12              -122.418229                      Fermentation Lab
# 13              -122.418229                           Whitechapel
# 14              -122.418229                         The Beer Hall
# 15              -122.418229                      Golden Era Vegan
# 16              -122.418229                          Bi-Rite Cafe
# 17              -122.418229          Bill Graham Civic Auditorium
# 18              -122.418229                         August 1 Five
# 19              -122.418229                        Andersen Bread
# 20              -122.418229                  Taube Atrium Theater
# 21              -122.418229                  Sunday at the Museum
# 22              -122.418229                    Blue Bottle Coffee
# 23              -122.418229                 Mela Tandoori Kitchen
# 24              -122.418229                           Books, Inc.
# 25              -122.418229              Sydney Goldstein Theater
# 26              -122.418229                            Fitness SF
# 27              -122.418229                     George and Lennie
# 28              -122.418229             Brenda's French Soul Food
# 29              -122.418229                              Poké Bar
# ..                      ...                                   ...
# 745             -122.406378                            Mo's Grill
# 746             -122.406378                             Franchino
# 747             -122.406378                      Z & Y Restaurant
# 748             -122.406378                   Baonecci Ristorante
# 749             -122.406378                         Caffe Trieste
# 750             -122.406378                  Yin Du Wonton Noodle
# 751             -122.406378                               Trestle
# 752             -122.406378                    Golden Gate Bakery
# 753             -122.406378               Banksy Mural: Airstrike
# 754             -122.406378                           Caffé Greco
# 755             -122.406378                Calzone's Pizza Cucina
# 756             -122.406378                         Vital Tealeaf
# 757             -122.406378                       Cold Drinks Bar
# 758             -122.406378                                Quince
# 759             -122.406378           Firenze by Night Ristorante
# 760             -122.406378                  Vallejo Street Steps
# 761             -122.406378                           Naked Lunch
# 762             -122.406378               Hunan Home's Restaurant
# 763             -122.406378                        The Baked Bear
# 764             -122.406378               Bow Bow Cocktail Lounge
# 765             -122.406378                             Roka Akor
# 766             -122.406378     William Stout Architectural Books
# 767             -122.406378                      House of Nanking
# 768             -122.406378                  Glow Yoga & Wellness
# 769             -122.406378                    Jack Kerouac Alley
# 770             -122.411328                          Coffman Pool
# 771             -122.411328                        Wilde Overlook
# 772             -122.411328                        Little Village
# 773             -122.411328                     Philosopher's Way
# 774             -122.411328                       Herz Playground
#
#      Venue Latitude  Venue Longitude                   Venue Category
# 0         37.780178      -122.416505                       Art Museum
# 1         37.777976      -122.420157                     Concert Hall
# 2         37.779548      -122.420953                     Concert Hall
# 3         37.781433      -122.417073                      Coffee Shop
# 4         37.778601      -122.420816                      Opera House
# 5         37.778580      -122.420798                     Dance Studio
# 6         37.779303      -122.418160            Street Food Gathering
# 7         37.778569      -122.420800            Performing Arts Venue
# 8         37.777111      -122.417967                   Massage Studio
# 9         37.779042      -122.420971                             Park
# 10        37.779315      -122.414790                          Theater
# 11        37.777693      -122.416353    Vegetarian / Vegan Restaurant
# 12        37.778368      -122.415313                         Beer Bar
# 13        37.782230      -122.418884                     Cocktail Bar
# 14        37.776837      -122.417916                         Beer Bar
# 15        37.781495      -122.416822    Vegetarian / Vegan Restaurant
# 16        37.778779      -122.417164                             Café
# 17        37.777824      -122.417315                      Music Venue
# 18        37.780537      -122.420188                Indian Restaurant
# 19        37.776906      -122.417400                           Bakery
# 20        37.779551      -122.420869            Performing Arts Venue
# 21        37.780025      -122.416066                 Asian Restaurant
# 22        37.776286      -122.416867                      Coffee Shop
# 23        37.781178      -122.419504                Indian Restaurant
# 24        37.781614      -122.420531                        Bookstore
# 25        37.777031      -122.420979            Performing Arts Venue
# 26        37.776313      -122.416645             Gym / Fitness Center
# 27        37.781701      -122.415213                      Coffee Shop
# 28        37.782896      -122.418897  Southern / Soul Food Restaurant
# 29        37.776507      -122.417254                       Poke Place
# ..              ...              ...                              ...
# 745       37.799181      -122.407279                            Diner
# 746       37.798392      -122.407672               Italian Restaurant
# 747       37.796112      -122.406078              Szechuan Restaurant
# 748       37.799697      -122.407783               Italian Restaurant
# 749       37.798670      -122.407339                      Coffee Shop
# 750       37.796957      -122.406486               Chinese Restaurant
# 751       37.796306      -122.404534          New American Restaurant
# 752       37.796435      -122.406734                           Bakery
# 753       37.797897      -122.406782                       Public Art
# 754       37.799035      -122.408389                             Café
# 755       37.799048      -122.408195               Italian Restaurant
# 756       37.796605      -122.406797                         Tea Room
# 757       37.798027      -122.407858                     Cocktail Bar
# 758       37.797412      -122.403258          New American Restaurant
# 759       37.798982      -122.408886               Italian Restaurant
# 760       37.799173      -122.404124                   Scenic Lookout
# 761       37.798023      -122.405741                   Sandwich Place
# 762       37.796193      -122.405581               Chinese Restaurant
# 763       37.798081      -122.407165                   Ice Cream Shop
# 764       37.797615      -122.406945                      Karaoke Bar
# 765       37.796336      -122.403850              Japanese Restaurant
# 766       37.796598      -122.403465                        Bookstore
# 767       37.796522      -122.405173               Jiangsu Restaurant
# 768       37.800125      -122.409114                      Yoga Studio
# 769       37.797583      -122.406443                 Pedestrian Plaza
# 770       37.713215      -122.415585                             Pool
# 771       37.718066      -122.412379                   Scenic Lookout
# 772       37.711959      -122.415101                     Liquor Store
# 773       37.718133      -122.412717                            Trail
# 774       37.713706      -122.416215                       Playground
#
# [775 rows x 7 columns]
